# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_psi=pd.read_csv("psi.csv", index_col=None)
df_psi_gto = pd.read_csv("../../../../cbasis/calc/h_pi/length_5opt/grid.csv", index_col=None)
plt.plot(df_psi["r"], df_psi["re_y"], label="DVR")
#plt.plot(df_psi["r"], df_psi["im_y"])
plt.plot(df_psi_gto["r"], -df_psi_gto["re_y"], label="FD")
#plt.xlim(0, 40)
plt.legend()
